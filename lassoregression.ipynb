# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np
import time 
import matplotlib.pyplot as plt

# %%
# Load the datasetata = "usedcars.csv"
train_data = 'test_data.csv'
train = pd.read_csv(train_data)

test_data = 'test_data.csv'
test = pd.read_csv(test_data)

# %%
X_train = train.drop(['price'], axis=1)
y_train = train['price']
X_test = test.drop(['price'], axis=1)
y_test = test['price']

# %%
# Lasso regression
lasso = Lasso(alpha=0.1)
start_lasso = time.time()
lasso.fit(X_train, y_train)
stop_lasso = time.time()
y_pred_lasso = lasso.predict(X_test)

print(stop_lasso - start_lasso)

mse_lasso = mean_squared_error(y_test, y_pred_lasso)
rmse_lasso = np.sqrt(mse_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)
mae_lasso = mean_absolute_error(y_test, y_pred_lasso)

# Print the results
print("\nLasso regression:")
print(f"MSE: {mse_lasso:.2f}, RMSE: {rmse_lasso:.2f}, R-squared: {r2_lasso:.2f}, MAE: {mae_lasso:.2f}")
# Out:
# 0.06283736228942871
#
# Lasso regression:
# MSE: 46.22, RMSE: 6.80, R-squared: 0.86, MAE: 5.13

# %%
y1pred =  lasso.predict(X_test) # predicting test data
y1_hat = lasso.predict(X_train) # predicting train data

# %%
# plotting trained price v/s predicted trained price
plt.scatter(y_train,y1_hat,s=0.5,c='b')
plt.plot(y_train,y_train,c='red')
plt.xlabel('trained y'); plt.ylabel('yhat')
plt.title("Plot of Train Data")
# Out:
# Text(0.5, 1.0, 'Plot of Train Data')

# %%
# plotting tested price v/s predicted tested price
plt.scatter(y_test,y1pred,s=0.5,c='b')
plt.plot(y_test,y_test,c='r')
plt.xlabel('Actual Data'); plt.ylabel('Predicted Data')
plt.title("Lasso Regression (with SelectKBest)")
# Out:
# Text(0.5, 1.0, 'Lasso Regression (with SelectKBest)')
